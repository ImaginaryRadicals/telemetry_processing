# %%
import parseCSV
import telemetryAnalysis
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import tkinter as tk
from tkinter import filedialog

# %%
matplotlib.rcParams['figure.figsize'] = [10, 6]

# %%
dataTable = parseCSV.getDictionary()
# Out:
# C:/MY_DATA/_9_Personal/FTC_Robotics/2017_FTC/telemetry_processing/telemetry1_defectiveBackLeftEncoder.csv
#
# ['time', 'red_channel', 'blue_channel', 'light_level', 'CLAW_LEFT', 'CLAW_RIGHT', 'JEWEL_ARM', 'DRIVE_FRONT_LEFT_ticks', 'DRIVE_FRONT_RIGHT_ticks', 'DRIVE_BACK_LEFT_ticks', 'DRIVE_BACK_RIGHT_ticks', 'ARM_MOTOR_ticks', 'DRIVE_FRONT_LEFT_power', 'DRIVE_FRONT_RIGHT_power', 'DRIVE_BACK_LEFT_power', 'DRIVE_BACK_RIGHT_power', 'ARM_MOTOR_power', 'x_in', 'y_in', 'theta_rad']

# %%
telemetryAnalysis.plotServos(dataTable)

# %%
telemetryAnalysis.plotSensorData(dataTable)

# %%
telemetryAnalysis.plotMotorData(dataTable,"ARM_MOTOR")

# %%
telemetryAnalysis.plotXYPosition(dataTable)

# %%
    # Display data for all motors
    driveMotors = ['DRIVE_FRONT_LEFT','DRIVE_FRONT_RIGHT',
                   'DRIVE_BACK_LEFT','DRIVE_BACK_RIGHT']
    for i,motor in enumerate(driveMotors):
        telemetryAnalysis.plotMotorData(dataTable,motor)
